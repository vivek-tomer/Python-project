# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Downloads/Titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# inspection of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Cabin"] = df["Cabin"].replace(" ","0")

# %%
# "Totalcharges" has been converted to float type 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# To check if there is any null values in dataset 
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# To check the number of null values in dataset columnwise.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# To check the number of null values in dataset as a whole
df.isnull().sum().sum()
# Out:
# 866

# %%
# description of a dataset
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# To check the duplicate in the whole dataset
df.duplicated().sum()
# Out:
# 0

# %%
# To check the duplicate in the dataset columnwise.
df['Pclass'].duplicated().sum()
# Out:
# 888

# %%
# To convert the data of "Survived" column from (0 and 1) to (Yes and No).
def conv(value):
    if value == 1:
        return "Yes"
    else:
        return "No"
# Apply this func to the df
df["Survived"] = df["Survived"].apply(conv)

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       No       3
# 1            2      Yes       1
# 2            3      Yes       3
# 3            4      Yes       1
# 4            5       No       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# check the number of people survived with the help of 'survived' column. using seaborn.
plt.figure(figsize= (2,2))     
sns.countplot(x=df['Survived'])
plt.show()

# %%
# To see the count of passenger's survived.
plt.figure(figsize= (2,3))     
ax = sns.countplot(x=df['Survived'])
ax.bar_label(ax.containers[0])
plt.title("Count of passenger's survived")
plt.show()

# %%
# To see the number of Survived passenger's in the % form.
plt.figure(figsize= (2,2))                                  # To reduce the chart size.
gb = df.groupby("Survived").agg({"Survived":"count"})
plt.pie(gb['Survived'], labels=gb.index, autopct= "%0.1f%%")    # (labels=gb.index)--> for yes/no in chart, (autopct= "%1.2f%%")--> for auto percentage in chart.
plt.title("percentage of passenger's survived", fontsize= 10)
plt.show()

# %%
# Exploring by gender first.
plt.figure(figsize= (2,2))  
sns.countplot(x="Sex", data= df, hue= "Survived")
plt.title("Survived by Gender")
plt.show()

# %%
# according to "Age"
plt.figure(figsize= (30,5))  
sns.countplot(x="Age", data= df, hue= "Survived")
plt.xticks(rotation=90, ha='right')
plt.title("Survived by Age")
plt.show()

# %% [markdown]
# Problem-solving questions and inclusion of advanced topics that are valuable for demonstrating practical application and advanced skills problem-solving questions that directly apply Pandas concepts to practical scenarios.

# %%
df[df['Name'].str.startswith('Q', na= False)]
# Out:
#      PassengerId Survived  Pclass  \
# 506          507      Yes       2
# 530          531      Yes       2
#
#                                               Name     Sex   Age  SibSp  \
# 506  Quick, Mrs. Frederick Charles (Jane Richards)  female  33.0      0
# 530                       Quick, Miss. Phyllis May  female   2.0      1
#
#      Parch Ticket  Fare Cabin Embarked  new_col
# 506      2  26360  26.0   NaN        S    253.5
# 530      1  26360  26.0   NaN        S    265.5

# %%
df[df['Name'].str.endswith('w', na= False)]
# Out:
#      PassengerId Survived  Pclass                        Name   Sex   Age  \
# 70            71       No       2  Jenkin, Mr. Stephen Curnow  male  32.0
# 388          389       No       3        Sadlier, Mr. Matthew  male   NaN
# 757          758       No       2    Bailey, Mr. Percy Andrew  male  18.0
#
#      SibSp  Parch      Ticket     Fare Cabin Embarked     new_col
# 70       0      0  C.A. 33111  10.5000   NaN        S   35.500000
# 388      0      0      367655   7.7292   NaN        Q  129.666667
# 757      0      0       29108  11.5000   NaN        S  379.000000

# %%
df[df['new_col'].astype(str).str.startswith('39', na= False)]
# Out:
#      PassengerId Survived  Pclass                           Name     Sex  \
# 78            79      Yes       2  Caldwell, Master. Alden Gates    male
# 116          117       No       3           Connors, Mr. Patrick    male
# 390          391      Yes       1     Carter, Mr. William Ernest    male
# 393          394      Yes       1         Newell, Miss. Marjorie  female
# 791          792       No       2            Gaskell, Mr. Alfred    male
# 795          796       No       2             Otter, Mr. Richard    male
#
#        Age  SibSp  Parch  Ticket     Fare    Cabin Embarked  new_col
# 78    0.83      0      2  248738   29.000      NaN        S     39.5
# 116  70.50      0      0  370369    7.750      NaN        Q     39.0
# 390  36.00      1      2  113760  120.000  B96 B98        S    391.0
# 393  23.00      1      0   35273  113.275      D36        C    394.0
# 791  16.00      0      0  239865   26.000      NaN        S    396.0
# ...

# %%
(df['new_col']== '57') & (df['Age']>35)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
(df['new_col']== '57') | (df['Age']>35)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool
